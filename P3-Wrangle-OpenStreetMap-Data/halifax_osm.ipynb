# %% [markdown]
# # Wrangle OpenStreetMap Data with SQL

# %% [markdown]
# By Trevor Cook

# %% [markdown]
# <h3>Project Summary</h3>

# %% [markdown]
# This project goes through the data wrangling process by extracting a metropolitan area on OpenStreetMap, converting it into xml format, uploading the data into a database, and performing queries on the database with SQL. Before exporting the data into xml files, an audit is performed to analyze whether there are any problems or inconsistencies with the data. These problems, such as inconsistent streen names, are then updated before exporting the data into xml files.

# %% [markdown]
# Map area: Halifax, Nova Scotia
#
# The map position that I chose for this project can be found at the following link: <br>https://www.openstreetmap.org/relation/1339656#map=10/44.7857/-63.2304
#
# The reason for choosing Halifax, NS as the OpenStreetMap area for my project is because I spent 4 years in this city attending Dalhousie University. Halifax is and always will be one of my favorite cities.

# %% [markdown]
# Map size: <br>
# halifax_canada.osm: 80.4 MB

# %% [markdown]
# <h3>Table of Contents</h3>

# %% [markdown]
# 1) Data Audit <br>
# 2) Problems Encountered <br>
# 3) Converting .csv files into Database <br>
# 4) Queries <br>
# 5) Conclusion

# %% [markdown]
# # Data Audit

# %%
# The schema that will be used for when converting the osm data into csv format

schema = {
    'node': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'lat': {'required': True, 'type': 'float', 'coerce': float},
            'lon': {'required': True, 'type': 'float', 'coerce': float},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'node_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    },
    'way': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'way_nodes': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'node_id': {'required': True, 'type': 'integer', 'coerce': int},
                'position': {'required': True, 'type': 'integer', 'coerce': int}
            }
        }
    },
    'way_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string', 'required': True}
            }
        }
    }
}

# %% [markdown]
# <h3>Street Names</h3>

# %%
import xml.etree.cElementTree as ET
import re
from collections import defaultdict
import pprint

# Makes a list of the street abbreviations and stores them in a set
# Audits the street names so that you can view any potential problems

osm_file = open("halifax_canada.osm", "r")

# This regular expression looks at the last word in the string as this is where I expect to see the street abbreviation show up.
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
street_types = defaultdict(set)

# Here is a list of several common street abbreviations that I expect to see in the data. 
expected = ["Street", "Avenue", "Boulevard", "Drive", "Place", "Road", "Court", "Lane"]

def audit_street_type(street_types, street_name):
    '''This audit pulls out unexpected street abbreviations which are not in this list above'''
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)
            
def print_sorted_dict(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print "%s: %d" % (k, v)
        
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit():
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    pprint.pprint(dict(street_types))

audit()
# Out:
# {'Blvd': set(['Topsail Blvd']),
#  'Circle': set(['South Ridge Circle']),
#  'Close': set(['Lanshaw Close', 'Loppie Close', 'Roxham Close']),
#  'Crescent': set(['Digby Crescent', 'Plateau Crescent']),
#  'Dr': set(['Novalea Dr']),
#  'Grove': set(['Promise Grove']),
#  'Highway': set(['Bedford Highway']),
#  'Hill': set(['Ioney Hill']),
#  'NS': set(['MUMFORD ROAD, HALIFAX NS']),
#  'Quinpool': set(['6487 Quinpool']),
#  'Rd': set(['6324 Quinpool Rd', 'Kempt Rd', 'Quinpool Rd']),
#  'Rd.': set(['6371 Quinpool Rd.']),
#  'Row': set(['Dresden Row']),
#  'Run': set(['Beech Tree Run']),
#  'St': set(['Gesner St', 'May St', 'Preston St']),
#  'St,': set(['Provo Wallis St,']),
#  'St.': set(['George St.']),
#  'Terrace': set(['Cannon Terrace', 'Milo Terrace']),
#  'Walk': set(['Lemon Walk']),
#  'Way': set(['Peakview Way', 'Whispering Way']),
#  'West': set(['Portland Estates Boulevard West', 'Sullivan Street West']),
#  'ave': set(['millbrook ave'])}

# %% [markdown]
# Based on this audit, we can see that there are several instances where the street abbreviations were not found in the expected list of names.
#
# The first type represents uncommon street abbreviations, such as Circle or Crescent. There is nothing wrong with these street types, they are simply more rare names that have not been included in the expected list.
#
# The second type is shortened street names, for example Dr or St. This data will have to be cleaned up by changing their names to Drive and Street, respectively.
#
# The data audit also shows an instance when the contributor included 'HALIFAX NS' in the street address.

# %% [markdown]
# <h3>Postal Codes</h3>

# %%
# Makes a list of the postal codes and stores them in a set
# Audits the postal codes so that you can view any potential problems

osm_file = open("halifax_canada.osm", "r")

# This regular expression looks at the first block of text in the string
postal_type_re = re.compile(r'\S+\.?', re.IGNORECASE)
postal_types = defaultdict(set)

# This is a list of the first 3 digits of postal codes found in Halifax
expected = ["B2W", "B2X", "B2Y", "B2Z", "B3B", "B3H", "B3J", "B3K", "B3L", "B3M", "B3N", "B3S", "B3T", "B4A", "B4C", "B4E"]

def audit_postal_type(postal_types, postal_name):
    '''This audit pulls out unexpected postal codes which are not in the list expected'''
    m = postal_type_re.search(postal_name)
    if m:
        postal_type = m.group()
        if postal_type not in expected:
            postal_types[postal_type].add(postal_name)
            
def print_sorted_dict(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print "%s: %d" % (k, v)
        
def is_postal_code(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit():
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "way":
            # Returns all subtags with name 'tag'
            for tag in elem.iter("tag"):
                if is_postal_code(tag):
                    audit_postal_type(postal_types, tag.attrib['v'])
    pprint.pprint(dict(postal_types))

audit()
# Out:
# {'B3L1B1': set(['B3L1B1']),
#  'B3L1J6': set(['B3L1J6']),
#  'B3S0E1': set(['B3S0E1']),
#  'B4E3B5': set(['B4E3B5']),
#  'NS': set(['NS B3J 1P2', 'NS B3L 1A6']),
#  'b2v0a2': set(['b2v0a2'])}

# %% [markdown]
# The audit for postal codes is similar to that done for the street types as it highlights any potential problems with the data. As we can see from the audit, there are a few opportunities for cleaning this data. The first problem is that not all of the postal codes are written in capital letters. There are also many cases where there is whitespace missing between each 3 character block. Finally, some postal codes begin with 'NS', followed by the postal code.
#
# After cleaning the data, each postal code will be written in the same format. They will be written in uppercase letters, and will contain a space following the first 3-character block of the postal code.

# %% [markdown]
# # Problems Encountered

# %% [markdown]
# <h3>Street Names</h3>

# %%
# Takes the problem street name and updates it to the correct name

import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = "halifax_canada.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

# Street names that need to be updated based on the audit.
mapping = { "St": "Street",
            "St.": "Street",
            "St,": "Street",
            "Ave": "Avenue",
            "ave": "Avenue",
            "Rd": "Road",
            "Rd.": "Road",
            "Blvd": "Boulevard",
            "Dr": "Drive",
            }


def audit_street_type(street_types, street_name):
    '''Adds the street type to a dictionary if it is not found in the 'expected' list'''
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)
            

def is_street_name(elem):
    '''Verifies whether the arrribute's key corresponds to a street type'''
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types


def update_name(name, mapping):
    '''Changes the incorrect street abbreviation to the correct abbreviation, as shown in the mapping dict.'''
    name_split = name.split()
    for key in mapping.keys():
        if key in name_split:
            name = ' '.join(name_split)
            name = name.replace(key, mapping[key])
    return name


def test():
    st_types = audit(OSMFILE)

    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name



test()
# Out:
# {'101-01': set(['Service Road HFX 101-01']),
#  '104': set(['1546 Barrington Street #104']),
#  '107': set(['Highway 107']),
#  '12': set(['1475 Lower Water Street, Suite 12']),
#  '2': set(['Highway 2']),
#  '3Z2': set(['1475 Lower Water St, Halifax, NS B3J 3Z2']),
#  '7': set(['Highway 7']),
#  'Arm': set(['Belmont On The Arm']),
#  'Ave': set(['Garland Ave']),
#  'Barrington': set(['Barrington']),
#  'Blvd': set(['Topsail Blvd']),
#  'Chebucto': set(['Chebucto']),
#  'Circle': set(['Blockade Circle',
#                 'Chebucto Circle',
#                 'Edzell Castle Circle',
#                 'Fieldwood Circle',
#                 'Haida Circle',
#                 'Lochiel Circle',
#                 'South Ridge Circle',
#                 'Wentworth Circle']),
#  'Close': set(['Banbury Close',
#                'Baroness Close',
#                'Berkshire Close',
#                'Brockhurst Close',
#                'Cairnwell Close',
#                'Candytuft Close',
#                'Canterbury Close',
#                'Caxton Close',
#                'Chessvale Close',
#                'Chipstone Close',
#                'Edgewater Close',
#                'Ferindonald Close',
#                'Gorsebud Close',
#                'Huxley Close',
#                'Kingsley Close',
#                'Lanshaw Close',
#                'Logiealmond Close',
#                'Loppie Close',
#                'McClure Close',
#                'Parkmount Close',
#                'Prestwick Close',
#                'Rosehurst Close',
#                'Roxham Close',
#                'Sandhurst Close',
#                'Seahawk Close',
#                'Southhaven Close',
#                'Suffolk Close',
#                'Thackeray Close',
#                'Wendover Close',
#                'Woodhaven Close',
#                'Woodsmere Close']),
#  'Connector': set(['Cowie Hill Connector']),
#  'Crescent': set(['Agincourt Crescent',
#                   'Ahmadi Crescent',
#                   'Ainslie Crescent',
#                   'Alma Crescent',
#                   'Alumni Crescent',
#                   'Amaranth Crescent',
#                   'Amethyst Crescent',
#                   'Aspen Way Crescent',
#                   'Attwood Crescent',
#                   'Avon Crescent',
#                   'Barry Crescent',
#                   'Beals Crescent',
#                   'Beaver Crescent',
#                   'Bellbrook Crescent',
#                   'Birchfield Crescent',
#                   'Boling Green Crescent',
#                   'Briarlynn Crescent',
#                   'Briarwood Crescent',
#                   'Byron Crescent',
#                   'Canary Crescent',
#                   'Cannon Crescent',
#                   'Carnaby Crescent',
#                   'Carnation Crescent',
#                   'Caroline Crescent',
#                   'Cedar Crescent',
#                   'Chameau Crescent',
#                   'Clermont Crescent',
#                   'Codroy Crescent',
#                   'Colonial Crescent',
#                   'Coronation Crescent',
#                   'Country Crescent',
#                   'Cranberry Crescent',
#                   'Culrain Crescent',
#                   'Deepwood Crescent',
#                   'Devon Crescent',
#                   'Digby Crescent',
#                   'Dillon Crescent',
#                   'Dipper Crescent',
#                   'Dominion Crescent',
#                   'Dorothy Crescent',
#                   'Douglas Crescent',
#                   'Driftwood Crescent',
#                   'Eagle Crescent',
#                   'Edgecombe Crescent',
#                   'Ellerslie Crescent',
#                   'Elmdale Crescent',
#                   'Elwin Crescent',
#                   'Emerald Crescent',
#                   'Feldspar Crescent',
#                   'Feruz Crescent',
#                   'Forestside Crescent',
#                   'Gammon Crescent',
#                   'Glenda Crescent',
#                   'Greenborough Crescent',
#                   'Greenvale Crescent',
#                   'Guildwood Crescent',
#                   'Hallmark Crescent',
#                   'Hampshire Crescent',
#                   'Harlington Crescent',
#                   'Havelock Crescent',
#                   'Heathside Crescent',
#                   'Highland Crescent',
#                   'Hillary Crescent',
#                   'Hillwood Crescent',
#                   'Hirandale Crescent',
#                   'Honeydale Crescent',
#                   'Huron Crescent',
#                   'Inglewood Crescent',
#                   'Ivylea Crescent',
#                   'Jeep Crescent',
#                   'Joel Crescent',
#                   'Juniper Crescent',
#                   'Katrina Crescent',
#                   'Killarney Crescent',
#                   'Kingfisher Crescent',
#                   'Kingston Crescent',
#                   'Knob Hill Crescent',
#                   'Lake Loon Crescent',
#                   'Lake Thomas Crescent',
#                   'Lakehigh Crescent',
#                   'Lakeridge Crescent',
#                   'Lakeshire Crescent',
#                   'Lawlor Crescent',
#                   'Litchfield Crescent',
#                   'Lodge Crescent',
#                   'Madeira Crescent',
#                   'Mark Crescent',
#                   'Mcquade Lake Crescent',
#                   'Meadowlark Crescent',
#                   'Melrose Crescent',
#                   'Montrose Crescent',
#                   'Navara Crescent',
#                   'Neptune Crescent',
#                   'Nestor Crescent',
#                   'Norman Crescent',
#                   'Oland Crescent',
#                   'Parkedge Crescent',
#                   'Pebblecreek Crescent',
#                   'Pine Hill Crescent',
#                   'Pinewood Crescent',
#                   'Plateau Crescent',
#                   'Pondicherry Crescent',
#                   'Quindora Crescent',
#                   'Ravine Park Crescent',
#                   'Ritcey Crescent',
#                   'Roxbury Crescent',
#                   'Serocco Crescent',
#                   'Serop Crescent',
#                   'Shalimar Crescent',
#                   'Shaw Crescent',
#                   'Sidney Crescent',
#                   'Sophia Crescent',
#                   'Southbrook Crescent',
#                   'Sovereign Crescent',
#                   'Spar Crescent',
#                   'Squadron Crescent',
#                   'Stonehaven Crescent',
#                   'Susie Lake Crescent',
#                   'Swan Crescent',
#                   'Tangmere Crescent',
#                   'Tantling Crescent',
#                   'True North Crescent',
#                   'Vicky Crescent',
#                   'Waterford Crescent',
#                   'Westfield Crescent',
#                   'Whimsical Lake Crescent',
#                   'Whitehall Crescent',
#                   'Wilbert Devoe Crescent',
#                   'Wilton Crescent',
#                   'Windfield Crescent',
#                   'Winona Crescent',
#                   'Woodward Crescent']),
#  'Cross': set(['Lincoln Cross', 'Stonewick Cross']),
#  'Dr': set(['Novalea Dr', 'Parkland Dr']),
#  'Dr.': set(['Alderney Dr.']),
#  'East': set(['Highway 103 East']),
#  'Extension': set(['Forest Hills Extension',
#                    'Gaston Rd Extension',
#                    'Lawnwood Extension',
#                    'Portland St Extension',
#                    'Yorkshire Ave Extension']),
#  'Garden': set(['Spring Garden']),
#  'Gate': set(['Hector Gate', 'Killkee Gate', 'Ryan Gate', 'Sweetbriar Gate']),
#  'Gottingen': set(['Gottingen']),
#  'Green': set(['Fiddlers Green', 'Hampton Green']),
#  'Grove': set(['Aspen Grove',
#                'Castlepark Grove',
#                'Collins Grove',
#                'Fairway Grove',
#                'Hillspire Grove',
#                'Kelvin Grove',
#                'Leyland Grove',
#                'Narrowleaf Grove',
#                'Promise Grove',
#                'Tupper Grove',
#                'Wenlock Grove']),
#  'Halifax': set(['1225 Barrington, Halifax']),
#  'Highway': set(['Bedford Highway']),
#  'Hill': set(['Foggy Hill',
#               'Havenbrook Hill',
#               'Ioney Hill',
#               'Jakemans Hill',
#               'Peachtree Hill']),
#  'Hollis': set(['Hollis']),
#  'Hollow': set(['Sleepy Hollow']),
#  'Loop': set(['Horace Loop', 'Prospectors Loop']),
#  'NS': set(['Barrington St, Halifax, NS',
#             'MUMFORD ROAD, HALIFAX NS',
#             'Quinpool Rd, Halifax, NS']),
#  'North': set(['Highway 102 North']),
#  'Parade': set(['Marine Parade']),
#  'Passage': set(['Fort York Passage']),
#  'Path': set(['Algonquin Path', 'Sunset Path']),
#  'Portland': set(['Portland']),
#  'Quinpool': set(['6455 Quinpool', '6487 Quinpool']),
#  'Range': set(['Willow Hill Range']),
#  'Rd': set(['5466 Spring Garden Rd',
#             '6024 Quinpool Rd',
#             '6054 Quinpool Rd',
#             '6058 Quinpool Rd',
#             '6070 Quinpool Rd',
#             '6080 Quinpool Rd',
#             '6092 Quinpool Rd',
#             '6273 Quinpool Rd',
#             '6281 Quinpool Rd',
#             '6290 Quinpool Rd',
#             '6302 Quinpool Rd',
#             '6303 Quinpool Rd',
#             '6310 Quinpool Rd',
#             '6311 Quinpool Rd',
#             '6324 Quinpool Rd',
#             '6386 Quinpool Rd',
#             '6430 Quinpool Rd',
#             'Boland Rd',
#             'Cobequid Rd',
#             'Courtney Rd',
#             'Kempt Rd',
#             'Lady Hammond Rd',
#             'Quinpool Rd',
#             'St Margarets Bay Rd',
#             'Windmill Rd']),
#  'Rd,': set(['6389 Quinpool Rd,']),
#  'Rd.': set(['6052 Quinpool Rd.',
#              '6066 Quinpool Rd.',
#              '6074 Quinpool Rd.',
#              '6086 Quinpool Rd.',
#              '6088 Quinpool Rd.',
#              '6297 Quinpool Rd.',
#              '6301 Quinpool Rd.',
#              '6371 Quinpool Rd.']),
#  'Ridge': set(['Collins Grove Ridge', 'Lier Ridge']),
#  'Row': set(['1649 Bedford Row',
#              '1650 Bedford Row',
#              'Bedford Row',
#              'Dresden Row',
#              'Foulis Row',
#              'Lemlair Row']),
#  'Row,': set(['1680 Bedford Row,']),
#  'Run': set(['Beech Tree Run',
#              'Burgee Run',
#              'Coldstream Run',
#              'Gatehouse Run',
#              'Sheppards Run',
#              'Viscount Run',
#              'Waterstone Run']),
#  'South': set(['Highway 102 South']),
#  'St': set(['1235 Barrington St',
#             '1239 Barrington St',
#             '1475 Lower Water St',
#             '1869 Upper Water St',
#             '2553 Agricola St',
#             '5189 South St',
#             'George St',
#             'Gesner St',
#             'May St',
#             'Preston St',
#             'Robie St',
#             'Sacville St',
#             'Upper Water St',
#             'Willett St']),
#  'St,': set(['Barrington St,', 'Provo Wallis St,']),
#  'St.': set(['1505 Barrington St.',
#              '1726 Argyle St.',
#              '1781 Upper Water St.',
#              '2526 Agricola St.',
#              '2570 Agricola St.',
#              '2576 Agricola St.',
#              '2594 Agricola St.',
#              '2595 Agricola St.',
#              '2605 Agricola St.',
#              '2606 Agricola St.',
#              '2629 Agricola St.',
#              '54 King St.',
#              '56 Portland St.',
#              '5775 Charles St.',
#              '5780 Agricola St.',
#              '69 Portland St.',
#              'Argyle St.',
#              'Barrington St.',
#              'Duke St.',
#              'George St.',
#              'Hollis St.',
#              'King St.',
#              'Lower Water St.',
#              'Portland St.',
#              'Prince St.',
#              'Upper Water St.']),
#  'Terrace': set(['Albany Terrace',
#                  'Armview Terrace',
#                  'Aubrey Terrace',
#                  'Beechwood Terrace',
#                  'Birchwood Terrace',
#                  'Black Duck Terrace',
#                  'Blenheim Terrace',
#                  'Cannon Terrace',
#                  'Cedarbank Terrace',
#                  'Churchill Terrace',
#                  'Firefly Terrace',
#                  'Foxwood Terrace',
#                  'Gale Terrace',
#                  'Graycourt Terrace',
#                  'Hilltop Terrace',
#                  'Lakeshore Park Terrace',
#                  'Lamont Terrace',
#                  'Lewis Lake Terrace',
#                  'Lindenwood Terrace',
#                  'Milo Terrace',
#                  'Nova Terrace',
#                  'Parkstone Terrace',
#                  'Pinewood Terrace',
#                  'Power Terrace',
#                  'Red Fern Terrace',
#                  'Regina Terrace',
#                  'Salmon River Terrace',
#                  'Sandlewood Terrace',
#                  'Scotch Pine Terrace',
#                  'Silverwood Terrace',
#                  'Skyvue Terrace',
#                  'Sullivan Terrace',
#                  'Sutherland Terrace',
#                  'Tower Terrace',
#                  'Trillium Terrace',
#                  'Waterside Terrace',
#                  'Waverly Terrace',
#                  'Webster Terrace',
#                  'Willowdale Terrace',
#                  'Woodbank Terrace']),
#  'Walk': set(['Cobalt Walk',
#               'Gleave Walk',
#               'Goldfinch Walk',
#               'Indigo Walk',
#               'Julies Walk',
#               'Lavender Walk',
#               'Lemon Walk',
#               'Meadow Green Walk',
#               'Meadow Walk',
#               'Orange Walk',
#               'Princes Walk']),
#  'Way': set(['Aarons Way',
#              'Abrams Way',
#              'Arbor Way',
#              'Becks Way',
#              'Bethany Way',
#              'Carolyns Way',
#              'Castine Way',
#              'Charlottetown Way',
#              'Covington Way',
#              'Disciples Way',
#              'Durham Way',
#              'Hampshire Way',
#              'Heathland Way',
#              'Hudson Way',
#              'Lauder Way',
#              'Lily Pond Way',
#              'Loon Haven Way',
#              'Osprey Way',
#              'Peakview Way',
#              'Raptor Way',
#              'Redoubt Way',
#              'Stratford Way',
#              'Summer Field Way',
#              'Surrey Way',
#              'Traverse Way',
#              'Trinity Way',
#              'Tulloch Way',
#              'Westphal Way',
#              'Whispering Way',
#              'Wilfred Jackson Way']),
#  'West': set(['Highway 103 West',
#               'Portland Estates Boulevard West',
#               'Sullivan Street West']),
#  'Woods': set(['Marlborough Woods']),
#  'ave': set(['millbrook ave']),
#  'barrington': set(['barrington']),
#  'floor)': set(['Barrington Street (3rd floor)']),
#  'street': set(['Gottingen street', 'Salter street'])}
# Portland => Portland
# Collins Grove Ridge => Collins Grove Ridge
# Lier Ridge => Lier Ridge
# Barrington St, => Barrington Street
# Provo Wallis St, => Provo Wallis Street
# Highway 103 West => Highway 103 West
# Sullivan Street West => Sullivan Street West
# Portland Estates Boulevard West => Portland Estates Boulevard West
# 2629 Agricola St. => 2629 Agricola Street
# 2570 Agricola St. => 2570 Agricola Street
# 2594 Agricola St. => 2594 Agricola Street
# 2605 Agricola St. => 2605 Agricola Street
# Duke St. => Duke Street
# 1505 Barrington St. => 1505 Barrington Street
# George St. => George Street
# 54 King St. => 54 King Street
# 5780 Agricola St. => 5780 Agricola Street
# Portland St. => Portland Street
# Prince St. => Prince Street
# 2576 Agricola St. => 2576 Agricola Street
# King St. => King Street
# 1781 Upper Water St. => 1781 Upper Water Street
# 1726 Argyle St. => 1726 Argyle Street
# Argyle St. => Argyle Street
# 2595 Agricola St. => 2595 Agricola Street
# 69 Portland St. => 69 Portland Street
# 5775 Charles St. => 5775 Charles Street
# Upper Water St. => Upper Water Street
# Lower Water St. => Lower Water Street
# 2606 Agricola St. => 2606 Agricola Street
# Hollis St. => Hollis Street
# 2526 Agricola St. => 2526 Agricola Street
# Barrington St. => Barrington Street
# 56 Portland St. => 56 Portland Street
# Alderney Dr. => Alderney Dr.
# Stonewick Cross => Stonewick Cross
# Lincoln Cross => Lincoln Cross
# Fort York Passage => Fort York Passage
# Cowie Hill Connector => Cowie Hill Connector
# Gottingen => Gottingen
# Gottingen street => Gottingen street
# Salter street => Salter street
# Jakemans Hill => Jakemans Hill
# Ioney Hill => Ioney Hill
# Havenbrook Hill => Havenbrook Hill
# Peachtree Hill => Peachtree Hill
# Foggy Hill => Foggy Hill
# Castine Way => Castine Way
# Redoubt Way => Redoubt Way
# Carolyns Way => Carolyns Way
# Tulloch Way => Tulloch Way
# Raptor Way => Raptor Way
# Lauder Way => Lauder Way
# Summer Field Way => Summer Field Way
# Hampshire Way => Hampshire Way
# Stratford Way => Stratford Way
# Westphal Way => Westphal Way
# Wilfred Jackson Way => Wilfred Jackson Way
# Peakview Way => Peakview Way
# Heathland Way => Heathland Way
# Becks Way => Becks Way
# Aarons Way => Aarons Way
# Hudson Way => Hudson Way
# Whispering Way => Whispering Way
# Arbor Way => Arbor Way
# Charlottetown Way => Charlottetown Way
# Lily Pond Way => Lily Pond Way
# Trinity Way => Trinity Way
# Disciples Way => Disciples Way
# Traverse Way => Traverse Way
# Bethany Way => Bethany Way
# Durham Way => Durham Way
# Osprey Way => Osprey Way
# Covington Way => Covington Way
# Surrey Way => Surrey Way
# Abrams Way => Abrams Way
# Loon Haven Way => Loon Haven Way
# 6389 Quinpool Rd, => 6389 Quinpool Rd,
# Sweetbriar Gate => Sweetbriar Gate
# Hector Gate => Hector Gate
# Ryan Gate => Ryan Gate
# Killkee Gate => Killkee Gate
# Edzell Castle Circle => Edzell Castle Circle
# Blockade Circle => Blockade Circle
# Chebucto Circle => Chebucto Circle
# South Ridge Circle => South Ridge Circle
# Haida Circle => Haida Circle
# Fieldwood Circle => Fieldwood Circle
# Lochiel Circle => Lochiel Circle
# Wentworth Circle => Wentworth Circle
# Sleepy Hollow => Sleepy Hollow
# Bedford Highway => Bedford Highway
# 6487 Quinpool => 6487 Quinpool
# 6455 Quinpool => 6455 Quinpool
# Highway 103 East => Highway 103 East
# Viscount Run => Viscount Run
# Beech Tree Run => Beech Tree Run
# Burgee Run => Burgee Run
# Gatehouse Run => Gatehouse Run
# Coldstream Run => Coldstream Run
# Waterstone Run => Waterstone Run
# Sheppards Run => Sheppards Run
# Spring Garden => Spring Garden
# Service Road HFX 101-01 => Service Road HFX 101-01
# Garland Ave => Garland Avenue
# Highway 2 => Highway 2
# Highway 102 South => Highway 102 South
# Highway 7 => Highway 7
# Sunset Path => Sunset Path
# Algonquin Path => Algonquin Path
# Barrington St, Halifax, NS => Barrington Street Halifax, NS
# Quinpool Rd, Halifax, NS => Quinpool Rd, Halifax, NS
# MUMFORD ROAD, HALIFAX NS => MUMFORD ROAD, HALIFAX NS
# Parkland Dr => Parkland Drive
# Novalea Dr => Novalea Drive
# Dipper Crescent => Dipper Crescent
# Codroy Crescent => Codroy Crescent
# Woodward Crescent => Woodward Crescent
# Tangmere Crescent => Tangmere Crescent
# True North Crescent => True North Crescent
# Southbrook Crescent => Southbrook Crescent
# Norman Crescent => Norman Crescent
# Knob Hill Crescent => Knob Hill Crescent
# Swan Crescent => Swan Crescent
# Alumni Crescent => Alumni Crescent
# Mcquade Lake Crescent => Mcquade Lake Crescent
# Wilbert Devoe Crescent => Wilbert Devoe Crescent
# Inglewood Crescent => Inglewood Crescent
# Lake Loon Crescent => Lake Loon Crescent
# Lakehigh Crescent => Lakehigh Crescent
# Hillwood Crescent => Hillwood Crescent
# Kingston Crescent => Kingston Crescent
# Parkedge Crescent => Parkedge Crescent
# Carnation Crescent => Carnation Crescent
# Havelock Crescent => Havelock Crescent
# Honeydale Crescent => Honeydale Crescent
# Stonehaven Crescent => Stonehaven Crescent
# Avon Crescent => Avon Crescent
# Chameau Crescent => Chameau Crescent
# Pebblecreek Crescent => Pebblecreek Crescent
# Waterford Crescent => Waterford Crescent
# Briarwood Crescent => Briarwood Crescent
# Byron Crescent => Byron Crescent
# Pinewood Crescent => Pinewood Crescent
# Hampshire Crescent => Hampshire Crescent
# Shalimar Crescent => Shalimar Crescent
# Feldspar Crescent => Feldspar Crescent
# Heathside Crescent => Heathside Crescent
# Huron Crescent => Huron Crescent
# Harlington Crescent => Harlington Crescent
# Carnaby Crescent => Carnaby Crescent
# Highland Crescent => Highland Crescent
# Ivylea Crescent => Ivylea Crescent
# Windfield Crescent => Windfield Crescent
# Dominion Crescent => Dominion Crescent
# Greenvale Crescent => Greenvale Crescent
# Bellbrook Crescent => Bellbrook Crescent
# Litchfield Crescent => Litchfield Crescent
# Hillary Crescent => Hillary Crescent
# Briarlynn Crescent => Briarlynn Crescent
# Jeep Crescent => Jeep Crescent
# Amethyst Crescent => Amethyst Crescent
# Lodge Crescent => Lodge Crescent
# Alma Crescent => Alma Crescent
# Dillon Crescent => Dillon Crescent
# Culrain Crescent => Culrain Crescent
# Pine Hill Crescent => Pine Hill Crescent
# Shaw Crescent => Shaw Crescent
# Neptune Crescent => Neptune Crescent
# Serop Crescent => Serop Crescent
# Oland Crescent => Oland Crescent
# Sidney Crescent => Sidney Crescent
# Joel Crescent => Joel Crescent
# Spar Crescent => Spar Crescent
# Ravine Park Crescent => Ravine Park Crescent
# Pondicherry Crescent => Pondicherry Crescent
# Driftwood Crescent => Driftwood Crescent
# Country Crescent => Country Crescent
# Birchfield Crescent => Birchfield Crescent
# Wilton Crescent => Wilton Crescent
# Ahmadi Crescent => Ahmadi Crescent
# Serocco Crescent => Serocco Crescent
# Glenda Crescent => Glenda Crescent
# Mark Crescent => Mark Crescent
# Squadron Crescent => Squadron Crescent
# Westfield Crescent => Westfield Crescent
# Plateau Crescent => Plateau Crescent
# Whitehall Crescent => Whitehall Crescent
# Sophia Crescent => Sophia Crescent
# Sovereign Crescent => Sovereign Crescent
# Devon Crescent => Devon Crescent
# Kingfisher Crescent => Kingfisher Crescent
# Meadowlark Crescent => Meadowlark Crescent
# Edgecombe Crescent => Edgecombe Crescent
# Susie Lake Crescent => Susie Lake Crescent
# Vicky Crescent => Vicky Crescent
# Whimsical Lake Crescent => Whimsical Lake Crescent
# Feruz Crescent => Feruz Crescent
# Melrose Crescent => Melrose Crescent
# Caroline Crescent => Caroline Crescent
# Ellerslie Crescent => Ellerslie Crescent
# Montrose Crescent => Montrose Crescent
# Deepwood Crescent => Deepwood Crescent
# Amaranth Crescent => Amaranth Crescent
# Barry Crescent => Barry Crescent
# Cannon Crescent => Cannon Crescent
# Canary Crescent => Canary Crescent
# Colonial Crescent => Colonial Crescent
# Guildwood Crescent => Guildwood Crescent
# Douglas Crescent => Douglas Crescent
# Eagle Crescent => Eagle Crescent
# Digby Crescent => Digby Crescent
# Ainslie Crescent => Ainslie Crescent
# Attwood Crescent => Attwood Crescent
# Gammon Crescent => Gammon Crescent
# Katrina Crescent => Katrina Crescent
# Hallmark Crescent => Hallmark Crescent
# Winona Crescent => Winona Crescent
# Emerald Crescent => Emerald Crescent
# Elwin Crescent => Elwin Crescent
# Beals Crescent => Beals Crescent
# Killarney Crescent => Killarney Crescent
# Nestor Crescent => Nestor Crescent
# Boling Green Crescent => Boling Green Crescent
# Lakeshire Crescent => Lakeshire Crescent
# Agincourt Crescent => Agincourt Crescent
# Navara Crescent => Navara Crescent
# Lake Thomas Crescent => Lake Thomas Crescent
# Juniper Crescent => Juniper Crescent
# Forestside Crescent => Forestside Crescent
# Hirandale Crescent => Hirandale Crescent
# Ritcey Crescent => Ritcey Crescent
# Aspen Way Crescent => Aspen Way Crescent
# Cedar Crescent => Cedar Crescent
# Coronation Crescent => Coronation Crescent
# Lakeridge Crescent => Lakeridge Crescent
# Lawlor Crescent => Lawlor Crescent
# Roxbury Crescent => Roxbury Crescent
# Clermont Crescent => Clermont Crescent
# Tantling Crescent => Tantling Crescent
# Dorothy Crescent => Dorothy Crescent
# Greenborough Crescent => Greenborough Crescent
# Quindora Crescent => Quindora Crescent
# Madeira Crescent => Madeira Crescent
# Beaver Crescent => Beaver Crescent
# Cranberry Crescent => Cranberry Crescent
# Elmdale Crescent => Elmdale Crescent
# 1546 Barrington Street #104 => 1546 Barrington Street #104
# Barrington => Barrington
# Lawnwood Extension => Lawnwood Extension
# Gaston Rd Extension => Gaston Road Extension
# Forest Hills Extension => Forest Hills Extension
# Yorkshire Ave Extension => Yorkshire Avenue Extension
# Portland St Extension => Portland Street Extension
# Castlepark Grove => Castlepark Grove
# Hillspire Grove => Hillspire Grove
# Aspen Grove => Aspen Grove
# Wenlock Grove => Wenlock Grove
# Narrowleaf Grove => Narrowleaf Grove
# Tupper Grove => Tupper Grove
# Collins Grove => Collins Grove
# Promise Grove => Promise Grove
# Leyland Grove => Leyland Grove
# Kelvin Grove => Kelvin Grove
# Fairway Grove => Fairway Grove
# Barrington Street (3rd floor) => Barrington Street (3rd floor)
# 2553 Agricola St => 2553 Agricola Street
# Sacville St => Sacville Street
# Preston St => Preston Street
# May St => May Street
# 1239 Barrington St => 1239 Barrington Street
# 1869 Upper Water St => 1869 Upper Water Street
# 5189 South St => 5189 South Street
# Robie St => Robie Street
# 1475 Lower Water St => 1475 Lower Water Street
# Willett St => Willett Street
# Upper Water St => Upper Water Street
# 1235 Barrington St => 1235 Barrington Street
# George St => George Street
# Gesner St => Gesner Street
# Topsail Blvd => Topsail Boulevard
# Willow Hill Range => Willow Hill Range
# Hampton Green => Hampton Green
# Fiddlers Green => Fiddlers Green
# Chebucto => Chebucto
# Highway 102 North => Highway 102 North
# 1680 Bedford Row, => 1680 Bedford Row,
# Highway 107 => Highway 107
# Horace Loop => Horace Loop
# Prospectors Loop => Prospectors Loop
# millbrook ave => millbrook Avenue
# 6430 Quinpool Rd => 6430 Quinpool Road
# 6311 Quinpool Rd => 6311 Quinpool Road
# 6058 Quinpool Rd => 6058 Quinpool Road
# 6024 Quinpool Rd => 6024 Quinpool Road
# 6386 Quinpool Rd => 6386 Quinpool Road
# 6080 Quinpool Rd => 6080 Quinpool Road
# 6302 Quinpool Rd => 6302 Quinpool Road
# Boland Rd => Boland Road
# 6281 Quinpool Rd => 6281 Quinpool Road
# St Margarets Bay Rd => Street Margarets Bay Rd
# 6310 Quinpool Rd => 6310 Quinpool Road
# 6054 Quinpool Rd => 6054 Quinpool Road
# Kempt Rd => Kempt Road
# 6290 Quinpool Rd => 6290 Quinpool Road
# Courtney Rd => Courtney Road
# 6273 Quinpool Rd => 6273 Quinpool Road
# 6324 Quinpool Rd => 6324 Quinpool Road
# 6303 Quinpool Rd => 6303 Quinpool Road
# Lady Hammond Rd => Lady Hammond Road
# 6092 Quinpool Rd => 6092 Quinpool Road
# Windmill Rd => Windmill Road
# Quinpool Rd => Quinpool Road
# Cobequid Rd => Cobequid Road
# 6070 Quinpool Rd => 6070 Quinpool Road
# 5466 Spring Garden Rd => 5466 Spring Garden Road
# barrington => barrington
# 1475 Lower Water Street, Suite 12 => 1475 Lower Water Street, Suite 12
# 6301 Quinpool Rd. => 6301 Quinpool Road
# 6088 Quinpool Rd. => 6088 Quinpool Road
# 6086 Quinpool Rd. => 6086 Quinpool Road
# 6052 Quinpool Rd. => 6052 Quinpool Road
# 6371 Quinpool Rd. => 6371 Quinpool Road
# 6297 Quinpool Rd. => 6297 Quinpool Road
# 6066 Quinpool Rd. => 6066 Quinpool Road
# 6074 Quinpool Rd. => 6074 Quinpool Road
# Marine Parade => Marine Parade
# Hollis => Hollis
# Gleave Walk => Gleave Walk
# Goldfinch Walk => Goldfinch Walk
# Orange Walk => Orange Walk
# Meadow Walk => Meadow Walk
# Lavender Walk => Lavender Walk
# Indigo Walk => Indigo Walk
# Julies Walk => Julies Walk
# Princes Walk => Princes Walk
# Lemon Walk => Lemon Walk
# Meadow Green Walk => Meadow Green Walk
# Cobalt Walk => Cobalt Walk
# Marlborough Woods => Marlborough Woods
# Regina Terrace => Regina Terrace
# Churchill Terrace => Churchill Terrace
# Webster Terrace => Webster Terrace
# Armview Terrace => Armview Terrace
# Scotch Pine Terrace => Scotch Pine Terrace
# Cedarbank Terrace => Cedarbank Terrace
# Hilltop Terrace => Hilltop Terrace
# Skyvue Terrace => Skyvue Terrace
# Willowdale Terrace => Willowdale Terrace
# Sandlewood Terrace => Sandlewood Terrace
# Salmon River Terrace => Salmon River Terrace
# Red Fern Terrace => Red Fern Terrace
# Trillium Terrace => Trillium Terrace
# Cannon Terrace => Cannon Terrace
# Gale Terrace => Gale Terrace
# Lakeshore Park Terrace => Lakeshore Park Terrace
# Woodbank Terrace => Woodbank Terrace
# Aubrey Terrace => Aubrey Terrace
# Graycourt Terrace => Graycourt Terrace
# Birchwood Terrace => Birchwood Terrace
# Parkstone Terrace => Parkstone Terrace
# Waterside Terrace => Waterside Terrace
# Lindenwood Terrace => Lindenwood Terrace
# Milo Terrace => Milo Terrace
# Firefly Terrace => Firefly Terrace
# Beechwood Terrace => Beechwood Terrace
# Black Duck Terrace => Black Duck Terrace
# Foxwood Terrace => Foxwood Terrace
# Sullivan Terrace => Sullivan Terrace
# Silverwood Terrace => Silverwood Terrace
# Lamont Terrace => Lamont Terrace
# Power Terrace => Power Terrace
# Albany Terrace => Albany Terrace
# Lewis Lake Terrace => Lewis Lake Terrace
# Sutherland Terrace => Sutherland Terrace
# Pinewood Terrace => Pinewood Terrace
# Tower Terrace => Tower Terrace
# Blenheim Terrace => Blenheim Terrace
# Waverly Terrace => Waverly Terrace
# Nova Terrace => Nova Terrace
# 1475 Lower Water St, Halifax, NS B3J 3Z2 => 1475 Lower Water Street Halifax, NS B3J 3Z2
# Parkmount Close => Parkmount Close
# Ferindonald Close => Ferindonald Close
# Huxley Close => Huxley Close
# Logiealmond Close => Logiealmond Close
# Southhaven Close => Southhaven Close
# Gorsebud Close => Gorsebud Close
# Kingsley Close => Kingsley Close
# Loppie Close => Loppie Close
# Caxton Close => Caxton Close
# Banbury Close => Banbury Close
# Brockhurst Close => Brockhurst Close
# Canterbury Close => Canterbury Close
# Chipstone Close => Chipstone Close
# Rosehurst Close => Rosehurst Close
# Chessvale Close => Chessvale Close
# Lanshaw Close => Lanshaw Close
# Berkshire Close => Berkshire Close
# Woodhaven Close => Woodhaven Close
# Baroness Close => Baroness Close
# Roxham Close => Roxham Close
# Sandhurst Close => Sandhurst Close
# Edgewater Close => Edgewater Close
# Suffolk Close => Suffolk Close
# Woodsmere Close => Woodsmere Close
# Seahawk Close => Seahawk Close
# Cairnwell Close => Cairnwell Close
# Prestwick Close => Prestwick Close
# McClure Close => McClure Close
# Wendover Close => Wendover Close
# Thackeray Close => Thackeray Close
# Candytuft Close => Candytuft Close
# 1225 Barrington, Halifax => 1225 Barrington, Halifax
# Belmont On The Arm => Belmont On The Arm
# Dresden Row => Dresden Row
# Foulis Row => Foulis Row
# 1650 Bedford Row => 1650 Bedford Row
# Lemlair Row => Lemlair Row
# Bedford Row => Bedford Row
# 1649 Bedford Row => 1649 Bedford Row

# %% [markdown]
# <h3>Postal Codes</h3>

# %%
OSMFILE = "halifax_canada.osm"
postal_type_re = re.compile(r'\b\S+\.?', re.IGNORECASE)

# This is a list of the first 3 digits of postal codes found in Halifax
expected_postal = ["B2W", "B2X", "B2Y", "B2Z", "B3B", "B3H", "B3J", "B3K", "B3L", "B3M", "B3N", "B3S", "B3T", "B4A", "B4C", "B4E"]

def audit_postal_type(postal_types, postal_name):
    '''Adds the postal code to a dictionary if it is not found in the 'expected' list'''
    m = postal_type_re.search(postal_name)
    if m:
        postal_type = m.group()
        if postal_type not in expected_postal:
            postal_types[postal_type].add(postal_name)
            
def is_postal_code(elem):
    '''Verifies whether the attribute's key corresponds to a postal code'''
    return (elem.attrib['k'] == "addr:postcode")


def audit_postal(osmfile):
    osm_file = open(osmfile, "r")
    postal_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_postal_code(tag):
                    audit_postal_type(postal_types, tag.attrib['v'])
    osm_file.close()
    return postal_types


def update_postal(name):
    '''Changes the postal codes to a consistent format'''
    if name[0] == "b":
        name = name.upper() # Capitalize lower case postal codes
    if name[0] == "N":
        name = name.split(" ")
        first, second = name[1], name[2]
        seq = (first, second)
        name = " ".join(seq) # Remove 'NS' from beginning of string
    if "-" in name:
        name = name.replace("-", " ") # Changes '-' to a space
    else:
        if len(name) == 6:
            # If the length of the string is 6, there is no space in between each 3-character block
            # This code splits the string in half and adds a space between them
            # Reference: http://stackoverflow.com/questions/4789601/split-a-string-into-2-in-python
            first, second = name[:len(name)/2], name[len(name)/2:]
            seq = (first, second)
            s = " "
            name = s.join(seq)      
    return name


def test():
    postal_types = audit_postal(OSMFILE)

    pprint.pprint(dict(postal_types))

    for postal_type, ways in postal_types.iteritems():
        for name in ways:
            better_name = update_postal(name)
            print name, "=>", better_name



test()
# Out:
# {'B3A': set(['B3A 1M6']),
#  'B3J1K1': set(['B3J1K1']),
#  'B3J1S5': set(['B3J1S5']),
#  'B3J1T2': set(['B3J1T2']),
#  'B3J1T3': set(['B3J1T3']),
#  'B3J1Z6': set(['B3J1Z6']),
#  'B3J3J4': set(['B3J3J4']),
#  'B3J3M7': set(['B3J3M7']),
#  'B3J3N4': set(['B3J3N4']),
#  'B3K1Y5': set(['B3K1Y5']),
#  'B3K2R4': set(['B3K2R4']),
#  'B3K4X5': set(['B3K4X5']),
#  'B3L1A7': set(['B3L1A7']),
#  'B3L1B1': set(['B3L1B1']),
#  'B3L1B2': set(['B3L1B2']),
#  'B3L1B6': set(['B3L1B6']),
#  'B3L1J6': set(['B3L1J6']),
#  'B3N2E5': set(['B3N2E5']),
#  'B3S0E1': set(['B3S0E1']),
#  'B3S1M8': set(['B3S1M8']),
#  'B3S1R1': set(['B3S1R1']),
#  'B4A-2R8': set(['B4A-2R8']),
#  'B4A4H5': set(['B4A4H5']),
#  'B4E3B5': set(['B4E3B5']),
#  'Halifax': set(['Halifax']),
#  'NS': set(['NS B3J 1P2', 'NS B3L 1A6', 'NS B4E 1R7']),
#  'b2v0a2': set(['b2v0a2']),
#  'b3J': set(['b3J 2A4']),
#  'b3k': set(['b3k 6r8']),
#  'b3k3b4': set(['b3k3b4'])}
# B3J3N4 => B3J 3N4
# b3k 6r8 => B3K 6R8
# B3J1S5 => B3J 1S5
# B3K2R4 => B3K 2R4
# B4A-2R8 => B4A 2R8
# Halifax => Halifax
# B3N2E5 => B3N 2E5
# B4A4H5 => B4A 4H5
# B3S1R1 => B3S 1R1
# B3K4X5 => B3K 4X5
# b3J 2A4 => B3J 2A4
# B3L1B1 => B3L 1B1
# B3L1B2 => B3L 1B2
# NS B3L 1A6 => B3L 1A6
# NS B4E 1R7 => B4E 1R7
# NS B3J 1P2 => B3J 1P2
# B3L1B6 => B3L 1B6
# B3L1J6 => B3L 1J6
# B3K1Y5 => B3K 1Y5
# B3J3M7 => B3J 3M7
# B3J1T2 => B3J 1T2
# B3J1T3 => B3J 1T3
# B3J1K1 => B3J 1K1
# B3S0E1 => B3S 0E1
# B3A 1M6 => B3A 1M6
# b3k3b4 => B3K 3B4
# B3J1Z6 => B3J 1Z6
# B4E3B5 => B4E 3B5
# B3S1M8 => B3S 1M8
# b2v0a2 => B2V 0A2
# B3J3J4 => B3J 3J4
# B3L1A7 => B3L 1A7

# %%
import csv
import codecs
import re
import xml.etree.cElementTree as ET

import cerberus

OSM_PATH = "/Users/tcook/Desktop/openStreetMap/halifax_canada.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


# ================================================== #
#               Update Name Functions                #
# ================================================== #

OSMFILE = "halifax_canada.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
postal_type_re = re.compile(r'\b\S+\.?', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

# This is a list of the first 3 digits of postal codes found in Halifax
expected_postal = ["B2W", "B2X", "B2Y", "B2Z", "B3B", "B3H", "B3J", "B3K", "B3L", "B3M", "B3N", "B3S", "B3T", "B4A", "B4C", "B4E"]

# Street names that need to be updated based on the audit.
mapping = { "St": "Street",
            "St.": "Street",
            "St,": "Street",
            "Ave": "Avenue",
            "ave": "Avenue",
            "Rd": "Road",
            "Rd.": "Road",
            "Blvd": "Boulevard",
            "Dr": "Drive",
            }

def audit_street_type(street_types, street_name):
    '''Adds the street type to a dictionary if it is not found in the 'expected' list'''
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)
            

def is_street_name(elem):
    '''Verifies whether the arrribute's key corresponds to a street type'''
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

def update_street(name, mapping):
    name_split = name.split()
    for key in mapping.keys():
        if key in name_split:
            name = ' '.join(name_split)
            name = name.replace(key, mapping[key])
    return name


# ===========  Postal Codes ===========  #

def audit_postal_type(postal_types, postal_name):
    '''Adds the postal code to a dictionary if it is not found in the 'expected' list'''
    m = postal_type_re.search(postal_name)
    if m:
        postal_type = m.group()
        if postal_type not in expected_postal:
            postal_types[postal_type].add(postal_name)
            
def is_postal_code(elem):
    '''Verifies whether the attribute's key corresponds to a postal code'''
    return (elem.attrib['k'] == "addr:postcode")


def audit_postal(osmfile):
    osm_file = open(osmfile, "r")
    postal_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_postal_code(tag):
                    audit_postal_type(postal_types, tag.attrib['v'])
    osm_file.close()
    return postal_types


def update_postal(name):
    '''Changes the postal codes to a consistent format'''
    if name[0] == "b":
        name = name.upper() # Capitalize lower case postal codes
    if name[0] == "N":
        name = name.split(" ")
        first, second = name[1], name[2]
        seq = (first, second)
        name = " ".join(seq) # Remove 'NS' from beginning of string
    if "-" in name:
        name = name.replace("-", " ") # Changes '-' to a space
    else:
        if len(name) == 6:
            # If the length of the string is 6, there is no space in between each 3-character block
            # This code splits the string in half and adds a space between them
            # Reference: http://stackoverflow.com/questions/4789601/split-a-string-into-2-in-python
            first, second = name[:len(name)/2], name[len(name)/2:]
            seq = (first, second)
            s = " "
            name = s.join(seq)      
    return name



# ================================================== #
#               Shape Element Function               #
# ================================================== #


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements
    
    # Reference: https://discussions.udacity.com/t/help-cleaning-data/169833/9
    # Traps the 'user' and 'uid's in NODE_FIELDS which have no values
    if element.tag == 'node':
        for node in NODE_FIELDS:
            try:
                node_attribs[node] = element.attrib[node]
            except:
                node_attribs[node] = "00000"
                pass
            
        
        for child in element:            
            if child.tag == 'tag':
                if is_street_name(child):
                    # Update street names
                    child.attrib['v'] = update_street(child.attrib['v'], mapping)
                elif is_postal_code(child):
                    #Update postal codes
                    child.attrib['v'] = update_postal(child.attrib['v'])

            
            node_tags_dict = {}
            node_tags_dict['id'] = element.attrib['id']
            node_tags_dict['value'] = child.attrib['v']
            m = PROBLEMCHARS.match(child.attrib['k'])
                        
            
            if m:
                continue
            else:
                if ':' in child.attrib['k']:
                    key_split = child.attrib['k'].split(":", 1)
                    node_tags_dict['type'] = key_split[0]
                    node_tags_dict['key'] = key_split[1]
                    tags.append(node_tags_dict)
                else:
                    node_tags_dict['type'] = 'regular'
                    node_tags_dict['key'] = child.attrib['k']
                    tags.append(node_tags_dict)
                            
        
        return {'node': node_attribs, 'node_tags': tags}

    
    elif element.tag == 'way':              
        
        for child in element:
            if child.tag == 'tag':
                if is_street_name(child):
                    # Update street names
                    child.attrib['v'] = update_street(child.attrib['v'], mapping)
                elif is_postal_code(child):
                    #Update postal codes
                    child.attrib['v'] = update_postal(child.attrib['v'])                     
        
        for field in WAY_FIELDS:
            way_attribs[field] = element.attrib[field]
            
        position = 0
        for child in element:
            if child.tag == 'tag':
                way_tags_dict = {}
                way_tags_dict['id'] = element.attrib['id']
                way_tags_dict['value'] = child.attrib['v']
                m = PROBLEMCHARS.match(child.attrib['k'])
                if m:
                    continue
                else:
                    if ':' in child.attrib['k']:
                        key_split = child.attrib['k'].split(":", 1)
                        way_tags_dict['type'] = key_split[0]
                        way_tags_dict['key'] = key_split[1]
                        tags.append(way_tags_dict)
                    else:
                        way_tags_dict['type'] = 'regular'
                        way_tags_dict['key'] = child.attrib['k']
                        tags.append(way_tags_dict)
        
            elif child.tag == 'nd':
                way_nodes_dict = {}
                way_nodes_dict['id'] = element.attrib['id']
                way_nodes_dict['node_id'] = child.attrib['ref']
                way_nodes_dict['position'] = position
                position += 1
                way_nodes.append(way_nodes_dict)
                    
                        
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}


# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_strings = (
            "{0}: {1}".format(k, v if isinstance(v, str) else ", ".join(v))
            for k, v in errors.iteritems()
        )
        raise cerberus.ValidationError(
            message_string.format(field, "\n".join(error_strings))
        )


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
#     Note: Validation is ~ 10X slower. For the project consider using a small
#     sample of the map when validating.
    process_map(OSM_PATH, validate=True)

# %% [markdown]
# # Converting .csv files into Database

# %%
import sqlite3
import csv
from pprint import pprint

# Reference: http://stackoverflow.com/questions/2887878/importing-a-csv-file-into-a-sqlite3-database-table-using-python

sqlite_file = 'halifaxdb.db'
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()

# Create the tables
cur.execute('''
    CREATE TABLE nodes_tags(id INTEGER, key TEXT, value TEXT, type TEXT)
''')
cur.execute('''
    CREATE TABLE ways_tags(id INTEGER, key TEXT, value TEXT, type TEXT)
''')
cur.execute('''
    CREATE TABLE ways_nodes(id INTEGER, node_id INTEGER, position INTEGER)
''')
cur.execute('''
    CREATE TABLE nodes(id INTEGER, lat DOUBLE PRECISION, lon DOUBLE PRECISION, user TEXT, uid INTEGER, version INTEGER, changeset INTEGER, timestamp TIMESTAMP)
''')
cur.execute('''
    CREATE TABLE ways(id INTEGER, user TEXT, uid INTEGER, version INTEGER, changeset INTEGER, timestamp TIMESTAMP)
''')

conn.commit()

# Read in the .csv files as a dict.
with open('nodes_tags.csv', 'rb') as fin:
    dr = csv.DictReader(fin)
    to_db = [(i['id'].decode("utf-8"), i['key'].decode("utf-8"), i['value'].decode("utf-8"), i['type'].decode("utf-8")) for i in dr]

with open('ways_tags.csv', 'rb') as fin2:
    dr2 = csv.DictReader(fin2)
    to_db2 = [(i['id'].decode("utf-8"), i['key'].decode("utf-8"), i['value'].decode("utf-8"), i['type'].decode("utf-8")) for i in dr2]

with open('ways_nodes.csv', 'rb') as fin3:
    dr3 = csv.DictReader(fin3)
    to_db3 = [(i['id'].decode("utf-8"), i['node_id'].decode("utf-8"), i['position'].decode("utf-8")) for i in dr3]

with open('nodes.csv', 'rb') as fin4:
    dr4 = csv.DictReader(fin4)
    to_db4 = [(i['id'].decode("utf-8"), i['lat'].decode("utf-8"), i['lon'].decode("utf-8"), i['user'].decode("utf-8"), i['uid'].decode("utf-8"), i['version'].decode("utf-8"), i['changeset'].decode("utf-8"), i['timestamp'].decode("utf-8")) for i in dr4]

with open('ways.csv', 'rb') as fin5:
    dr5 = csv.DictReader(fin5)
    to_db5 = [(i['id'].decode("utf-8"), i['user'].decode("utf-8"), i['uid'].decode("utf-8"), i['version'].decode("utf-8"), i['changeset'].decode("utf-8"), i['timestamp'].decode("utf-8")) for i in dr5]
    
# Insert formatted data
cur.executemany("INSERT INTO nodes_tags(id, key, value, type) VALUES (?, ?, ?, ?);", to_db)
cur.executemany("INSERT INTO ways_tags(id, key, value, type) VALUES (?, ?, ?, ?);", to_db2)
cur.executemany("INSERT INTO ways_nodes(id, node_id, position) VALUES (?, ?, ?);", to_db3)
cur.executemany("INSERT INTO nodes(id, lat, lon, user, uid, version, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?, ?, ?);", to_db4)
cur.executemany("INSERT INTO ways(id, user, uid, version, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?);", to_db5)

# %% [markdown]
# # Queries

# %%
# Number of nodes

cur.execute('''
SELECT count(*) FROM nodes
''')
all_rows = cur.fetchall()
print "1) Number of nodes"
pprint(all_rows)
# Out:
# 1) Number of nodes
# [(379161,)]

# %%
# Number of ways

cur.execute('''
SELECT count(*) FROM ways
''')
all_rows = cur.fetchall()
print "2) Number of ways"
pprint(all_rows)
# Out:
# 2) Number of ways
# [(33193,)]

# %%
# Number of unique users

cur.execute('''
SELECT count(DISTINCT(e.uid))
FROM (SELECT uid FROM nodes UNION ALL SELECT uid FROM ways) as e
''')
all_rows = cur.fetchall()
print "3) Number of unique users"
pprint(all_rows)
# Out:
# 3) Number of unique users
# [(355,)]

# %%
# Top 10 contributors to the Halifax OpenStreetMap

cur.execute('''
SELECT e.user, COUNT(*) as num
FROM (SELECT user FROM nodes UNION ALL SELECT user FROM ways) as e
GROUP BY e.user
ORDER BY num DESC
LIMIT 10
''')
all_rows = cur.fetchall()
print "4) Top 10 contributors"
pprint(all_rows)
# Out:
# 4) Top 10 contributors
# [(u'macgregor', 190976),
#  (u'timdine', 136514),
#  (u'ingalls', 28210),
#  (u'Steve in Halifax', 9499),
#  (u'StewartSR', 8185),
#  (u'kavurt', 6573),
#  (u'BrianCumminger', 3851),
#  (u'dgenge', 2569),
#  (u'Dmajackson', 2147),
#  (u'whitebuffalo', 1977)]

# %%
# Top 10 types of food

cur.execute('''
SELECT value, COUNT(*) as num
FROM nodes_tags
WHERE key='cuisine'
GROUP BY value
ORDER BY num DESC
LIMIT 10
''')
all_rows = cur.fetchall()
print "5) Top 10 types of food"
pprint(all_rows)
# Out:
# 5) Top 10 types of food
# [(u'pizza', 20),
#  (u'burger', 17),
#  (u'coffee_shop', 13),
#  (u'chinese', 8),
#  (u'greek', 6),
#  (u'sandwich', 5),
#  (u'sushi', 4),
#  (u'japanese', 3),
#  (u'mediterranean', 3),
#  (u'mexican', 3)]

# %%
# Top 5 sport facilities

cur.execute('''
SELECT ways_tags.value, COUNT(*) as count
FROM ways_tags
WHERE key='sport'
GROUP BY ways_tags.value
ORDER BY count DESC
LIMIT 5
''')
all_rows = cur.fetchall()
print "6) Top 5 sport facilities"
pprint(all_rows)
# Out:
# 6) Top 5 sport facilities
# [(u'baseball', 88),
#  (u'soccer', 57),
#  (u'tennis', 39),
#  (u'basketball', 36),
#  (u'golf', 27)]

# %%
# Looks at the postal codes in the database

cur.execute('''
SELECT tags.value, COUNT(*) as count 
FROM (SELECT * FROM nodes_tags UNION ALL SELECT * FROM ways_tags) as tags 
WHERE tags.key='postcode' 
GROUP BY tags.value 
ORDER BY count DESC
LIMIT 5
''')
all_rows = cur.fetchall()
print "7) Top 5 Halifax postal codes"
pprint(all_rows)
# Out:
# 7) Top 5 Halifax postal codes
# [(u'B3T 2H8', 42),
#  (u'B2W 4A2', 38),
#  (u'B2W 2X6', 36),
#  (u'B3S 1G2', 36),
#  (u'B2W 2W5', 33)]

# %%
# Sort cities by count

cur.execute('''
SELECT tags.value, COUNT(*) as count
FROM (SELECT * FROM nodes_tags UNION ALL SELECT * FROM ways_tags) tags
WHERE tags.key='city'
GROUP BY tags.value
ORDER BY count DESC
LIMIT 5
''')
all_rows = cur.fetchall()
print "8) List of top 5 cities in Halifax Regional Municipality"
pprint(all_rows)
# Out:
# 8) List of top 5 cities in Halifax Regional Municipality
# [(u'Halifax', 7315),
#  (u'Dartmouth', 4290),
#  (u'Cole Harbour', 1718),
#  (u'Eastern Passage', 1159),
#  (u'Westphal', 720)]

# %%
# Number of contributions made in 2016

cur.execute('''
SELECT COUNT(*) as count
FROM (SELECT timestamp FROM nodes UNION ALL SELECT timestamp FROM ways) as i
WHERE i.timestamp LIKE '%2016%'
''')
all_rows = cur.fetchall()
print "9) Number of contributions made in 2016"
pprint(all_rows)
# Out:
# 9) Number of contributions made in 2016
# [(9330,)]

# %%
conn.close()

# %% [markdown]
# # Conclusion and Suggestions for Improvement

# %% [markdown]
# By bringing the Halifax OpenStreetMap data into a database and performing queries on it, we can pull out a lot of interesting information about the dataset. However, by looking at some of the results, there is a lot of room for improvement. One way that would improve this data is to remove any further inconsistencies, as was done during the audit for street name abbreviations and postal codes. This would save the data analyst a lot of time since much of their energy goes towards wrangling the data.
#
# OpenStreetMap could implement an audit each time a user contributes to their data, in order to ensure that similar data is written in a consistent format. For example, if a postal code in Halifax was inputed as b3h2j1, OpenStreetMap would convert this data into the standard format B3H 2J1.
#
# Alternatively, rather than having OpenStreetMap audit all the data that enters their system, they could encourage users to edit other people's contributions. If it were set up in a similar was as how Wikipedia double checks the credibility of each contribution made on their site, the data on OpenStreetMap would more likely be cleaner data and therefore would require less wrangling.
#
# The benefits of improving these inconsistencies with the data is that it would clean up and ensure that everything is written in the same format. On the downside, OpenStreetMap may not want to change the input generated by its users. There is also a chance that this type of audit does not change every piece of data to the correct format, causing additional errors in the data.
#
# Although there are still a few errors that could be fixed with the dataset, I think that the queries I performed have still given me a good idea of the Halifax OpenStreetMap layout.
